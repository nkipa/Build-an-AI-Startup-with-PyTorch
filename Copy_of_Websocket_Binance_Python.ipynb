# %% [markdown]
# <a href="https://colab.research.google.com/github/nkipa/Build-an-AI-Startup-with-PyTorch/blob/master/Copy_of_Websocket_Binance_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install websocket-client

# %%
import websocket, json

# %%
cc = 'btcusd'
interval = '1m'

# %%
socket = f'wss://stream.binance.com:9443/ws/{cc}t@kline_{interval}'

# %%
socket
# Out:
# 'wss://stream.binance.com:9443/ws/btcusdt@kline_1m'

# %%
closes, highs, lows = [], [], []

# %%
# making candlesticks

def on_message(ws, message):
    json_message = json.loads(message)
    candle = json_message['k']
    is_candle_closed = candle['x']
    close = candle['c']
    high = candle ['h']
    low = candle['l']
    vol = candle['v']

    if is_candle_closed:
      closes.append(float(close))
      highs.append(float(high))
      lows.append(float(low))

      print(closes)
      print(highs)
      print(lows)

def on_close(ws, close_status_code, close_msg):
    print("Connection Closed")

ws = websocket.WebSocketApp(socket,on_message = on_message, on_close = on_close)

# %%
ws.run_forever()
# Out:
# [36871.76]
# [36871.93]
# [36850.0]
# [36871.76, 36843.88]
# [36871.93, 36883.36]
# [36850.0, 36839.67]
# [36871.76, 36843.88, 36888.95]
# [36871.93, 36883.36, 36889.86]
# [36850.0, 36839.67, 36843.87]
# [36871.76, 36843.88, 36888.95, 36911.49]
# [36871.93, 36883.36, 36889.86, 36969.52]
# [36850.0, 36839.67, 36843.87, 36877.54]
# [36871.76, 36843.88, 36888.95, 36911.49, 36901.2]
# [36871.93, 36883.36, 36889.86, 36969.52, 36919.99]
# [36850.0, 36839.67, 36843.87, 36877.54, 36892.01]
# [36871.76, 36843.88, 36888.95, 36911.49, 36901.2, 36899.44]
# [36871.93, 36883.36, 36889.86, 36969.52, 36919.99, 36935.32]
# [36850.0, 36839.67, 36843.87, 36877.54, 36892.01, 36890.06]
# [36871.76, 36843.88, 36888.95, 36911.49, 36901.2, 36899.44, 36879.01]
# [36871.93, 36883.36, 36889.86, 36969.52, 36919.99, 36935.32, 36899.43]
# [36850.0, 36839.67, 36843.87, 36877.54, 36892.01, 36890.06, 36872.68]
# [36871.76, 36843.88, 36888.95, 36911.49, 36901.2, 36899.44, 36879.01, 36826.08]
# ...
